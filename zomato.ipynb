# %%
pwd
# Out:
# 'C:\\Users\\Hp\\DataScienceCourse'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
zomato_real = pd.read_csv('zomato.csv')

# %%
zomato_real
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
type(zomato_real)
# Out:
# pandas.core.frame.DataFrame

# %%
zomato_real.shape
# Out:
# (51717, 17)

# %%
zomato_real.head(8)
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
# 5  https://www.zomato.com/bangalore/timepass-dinn...
# 6  https://www.zomato.com/bangalore/rosewood-inte...
# 7  https://www.zomato.com/bangalore/onesta-banash...
#
#                                              address  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2  1112, Next to KIMS Medical College, 17th Cross...
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# 5  37, 5-1, 4th Floor, Bosco Court, Gandhi Bazaar...
# 6  19/1, New Timberyard Layout, Beside Satellite ...
# 7  2469, 3rd Floor, 24th Cross, Opposite BDA Comp...
#
# ...

# %%
zomato_real.tail(8)
# Out:
#                                                      url  \
# 51709  https://www.zomato.com/bangalore/the-farm-hous...
# 51710  https://www.zomato.com/bangalore/topsy-turvey-...
# 51711  https://www.zomato.com/bangalore/bhagini-2-whi...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 51709  136, SAP Labs India, KIADB Export Promotion In...
# 51710  2E2, 4th Cross Road, Devasandra Industrial Est...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# ...

# %%
zomato_real.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
zomato_real.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
zomato1 = zomato_real.drop(['url','dish_liked','phone'],axis=1)

# %%
zomato1.shape
# Out:
# (51717, 14)

# %%
zomato1.head()
# Out:
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes      location            rest_type  \
# 0          Yes        Yes  4.1/5    775  Banashankari        Casual Dining
# 1          Yes         No  4.1/5    787  Banashankari        Casual Dining
# 2          Yes         No  3.8/5    918  Banashankari  Cafe, Casual Dining
# 3           No         No  3.7/5     88  Banashankari          Quick Bites
# 4           No         No  3.8/5    166  Basavanagudi        Casual Dining
#
# ...

# %%
zomato1.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51712    False
# 51713    False
# 51714    False
# 51715    False
# 51716    False
# Length: 51717, dtype: bool

# %%
zomato1.duplicated().sum()
# Out:
# 43

# %%
51716-43
# Out:
# 51673

# %%
zomato1.drop_duplicates(inplace=True)

# %%
zomato1.shape
# Out:
# (51674, 14)

# %%
zomato1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51674 entries, 0 to 51716
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   address                      51674 non-null  object
#  1   name                         51674 non-null  object
#  2   online_order                 51674 non-null  object
#  3   book_table                   51674 non-null  object
#  4   rate                         43907 non-null  object
#  5   votes                        51674 non-null  int64
#  6   location                     51653 non-null  object
#  7   rest_type                    51447 non-null  object
#  8   cuisines                     51629 non-null  object
#  9   approx_cost(for two people)  51329 non-null  object
#  10  reviews_list                 51674 non-null  object
#  11  menu_item                    51674 non-null  object
#  12  listed_in(type)              51674 non-null  object
# ...

# %%
zomato1.isnull()
# Out:
#        address   name  online_order  book_table   rate  votes  location  \
# 0        False  False         False       False  False  False     False
# 1        False  False         False       False  False  False     False
# 2        False  False         False       False  False  False     False
# 3        False  False         False       False  False  False     False
# 4        False  False         False       False  False  False     False
# ...        ...    ...           ...         ...    ...    ...       ...
# 51712    False  False         False       False  False  False     False
# 51713    False  False         False       False   True  False     False
# 51714    False  False         False       False   True  False     False
# 51715    False  False         False       False  False  False     False
# 51716    False  False         False       False  False  False     False
#
#        rest_type  cuisines  approx_cost(for two people)  reviews_list  \
# ...

# %%
zomato1.isnull().sum()
# Out:
# address                           0
# name                              0
# online_order                      0
# book_table                        0
# rate                           7767
# votes                             0
# location                         21
# rest_type                       227
# cuisines                         45
# approx_cost(for two people)     345
# reviews_list                      0
# menu_item                         0
# listed_in(type)                   0
# listed_in(city)                   0
# dtype: int64

# %%
zomato1.dropna(how='any',inplace=True) #drop all missing values

# %%
zomato1.shape
# Out:
# (43499, 14)

# %%
zomato1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43499 entries, 0 to 51716
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   address                      43499 non-null  object
#  1   name                         43499 non-null  object
#  2   online_order                 43499 non-null  object
#  3   book_table                   43499 non-null  object
#  4   rate                         43499 non-null  object
#  5   votes                        43499 non-null  int64
#  6   location                     43499 non-null  object
#  7   rest_type                    43499 non-null  object
#  8   cuisines                     43499 non-null  object
#  9   approx_cost(for two people)  43499 non-null  object
#  10  reviews_list                 43499 non-null  object
#  11  menu_item                    43499 non-null  object
#  12  listed_in(type)              43499 non-null  object
# ...

# %%
zomato1.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'location', 'rest_type', 'cuisines', 'approx_cost(for two people)',
#        'reviews_list', 'menu_item', 'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
zomato2 =zomato1.rename(columns={'approx_cost(for two people)':'cost','listed_in(type)':'type','listed_in(city)':'city'})

# %%
zomato2.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'location', 'rest_type', 'cuisines', 'cost', 'reviews_list',
#        'menu_item', 'type', 'city'],
#       dtype='object')

# %%
zomato2['rate']
# Out:
# 0         4.1/5
# 1         4.1/5
# 2         3.8/5
# 3         3.7/5
# 4         3.8/5
#           ...
# 51709    3.7 /5
# 51711    2.5 /5
# 51712    3.6 /5
# 51715    4.3 /5
# 51716    3.4 /5
# Name: rate, Length: 43499, dtype: object

# %%
zomato2['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 'NEW', '2.9/5', '3.5/5', '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '-', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
zomato2['rate']!='NEW'
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 51709    True
# 51711    True
# 51712    True
# 51715    True
# 51716    True
# Name: rate, Length: 43499, dtype: bool

# %%
zomato2[zomato2['rate']!='NEW']
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51709  136, SAP Labs India, KIADB Export Promotion In...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# ...

# %%
zomato4 = zomato2[zomato2['rate']!='NEW']

# %%
zomato4['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', '2.9/5', '3.5/5', '2.6/5', '3.8 /5', '3.4/5', '4.5/5',
#        '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5', '3.4 /5',
#        '-', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5', '4.1 /5',
#        '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5', '3.5 /5',
#        '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5', '4.3 /5',
#        '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5', '4.9 /5',
#        '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5', '2.1 /5',
#        '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
zomato4['rate']!='-'
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 51709    True
# 51711    True
# 51712    True
# 51715    True
# 51716    True
# Name: rate, Length: 41302, dtype: bool

# %%
zomato4[zomato4['rate']!='-']
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51709  136, SAP Labs India, KIADB Export Promotion In...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# ...

# %%
zomato5 = zomato4[zomato4['rate']!='-']

# %%
zomato5['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', '2.9/5', '3.5/5', '2.6/5', '3.8 /5', '3.4/5', '4.5/5',
#        '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5', '3.4 /5',
#        '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5', '4.1 /5',
#        '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5', '3.5 /5',
#        '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5', '4.3 /5',
#        '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5', '4.9 /5',
#        '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5', '2.1 /5',
#        '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
lambda v:v.replace('/5','') if type(v) == np.str else v
# Out:
# <function __main__.<lambda>(v)>

# %%
remove_slash = lambda v:v.replace('/5','') if type(v) == np.str else v  #it will replace '/5' into nothing means empty string ''

# %%
'    hello   '.strip() #remove spaces which we dont need
# Out:
# 'hello'

# %%
zomato5['rate'].apply(remove_slash).str.strip().astype('float')
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_22008\1683548685.py:1: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   remove_slash = lambda v:v.replace('/5','') if type(v) == np.str else v  #it will replace '/5' into nothing means empty string ''
# 0        4.1
# 1        4.1
# 2        3.8
# 3        3.7
# 4        3.8
#         ...
# 51709    3.7
# 51711    2.5
# 51712    3.6
# 51715    4.3
# 51716    3.4
# Name: rate, Length: 41237, dtype: float64

# %%
zomato5['rate']
# Out:
# 0         4.1/5
# 1         4.1/5
# 2         3.8/5
# 3         3.7/5
# 4         3.8/5
#           ...
# 51709    3.7 /5
# 51711    2.5 /5
# 51712    3.6 /5
# 51715    4.3 /5
# 51716    3.4 /5
# Name: rate, Length: 41237, dtype: object

# %%
zomato5['rate'] = zomato5['rate'].apply(remove_slash).str.strip().astype('float') # astype will convert the string into float
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_22008\1683548685.py:1: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   remove_slash = lambda v:v.replace('/5','') if type(v) == np.str else v  #it will replace '/5' into nothing means empty string ''
# C:\Users\Hp\AppData\Local\Temp\ipykernel_22008\1126324861.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
zomato5
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51709  136, SAP Labs India, KIADB Export Promotion In...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# ...

# %%
zomato5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41237 entries, 0 to 51716
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   address       41237 non-null  object
#  1   name          41237 non-null  object
#  2   online_order  41237 non-null  object
#  3   book_table    41237 non-null  object
#  4   rate          41237 non-null  float64
#  5   votes         41237 non-null  int64
#  6   location      41237 non-null  object
#  7   rest_type     41237 non-null  object
#  8   cuisines      41237 non-null  object
#  9   cost          41237 non-null  object
#  10  reviews_list  41237 non-null  object
#  11  menu_item     41237 non-null  object
#  12  type          41237 non-null  object
#  13  city          41237 non-null  object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 4.7+ MB

# %%
zomato5['cost']
# Out:
# 0          800
# 1          800
# 2          800
# 3          300
# 4          600
#          ...
# 51709      800
# 51711      800
# 51712    1,500
# 51715    2,500
# 51716    1,500
# Name: cost, Length: 41237, dtype: object

# %%
zomato5['cost'] = zomato5['cost'].astype(str)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_22008\1963470220.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zomato5['cost'] = zomato5['cost'].astype(str)

# %%
zomato5['cost'] = zomato5['cost'].apply(lambda x:x.replace(',','.'))
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_22008\2877654386.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zomato5['cost'] = zomato5['cost'].apply(lambda x:x.replace(',','.'))

# %%
zomato5['cost'] = zomato5['cost'].astype(float)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_22008\3368708646.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zomato5['cost'] = zomato5['cost'].astype(float)

# %%
zomato5['cost']
# Out:
# 0        800.0
# 1        800.0
# 2        800.0
# 3        300.0
# 4        600.0
#          ...
# 51709    800.0
# 51711    800.0
# 51712      1.5
# 51715      2.5
# 51716      1.5
# Name: cost, Length: 41237, dtype: float64

# %%
zomato5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41237 entries, 0 to 51716
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   address       41237 non-null  object
#  1   name          41237 non-null  object
#  2   online_order  41237 non-null  object
#  3   book_table    41237 non-null  object
#  4   rate          41237 non-null  float64
#  5   votes         41237 non-null  int64
#  6   location      41237 non-null  object
#  7   rest_type     41237 non-null  object
#  8   cuisines      41237 non-null  object
#  9   cost          41237 non-null  float64
#  10  reviews_list  41237 non-null  object
#  11  menu_item     41237 non-null  object
#  12  type          41237 non-null  object
#  13  city          41237 non-null  object
# dtypes: float64(2), int64(1), object(11)
# memory usage: 4.7+ MB

# %%
zomato5.head(3)
# Out:
#                                              address             name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...            Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...   Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...  San Churro Cafe
#
#   online_order book_table  rate  votes      location            rest_type  \
# 0          Yes        Yes   4.1    775  Banashankari        Casual Dining
# 1          Yes         No   4.1    787  Banashankari        Casual Dining
# 2          Yes         No   3.8    918  Banashankari  Cafe, Casual Dining
#
#                          cuisines   cost  \
# 0  North Indian, Mughlai, Chinese  800.0
# 1     Chinese, North Indian, Thai  800.0
# 2          Cafe, Mexican, Italian  800.0
#
#                                         reviews_list menu_item    type  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []  Buffet
# ...

# %%
zomato5['name'] = zomato5['name'].apply(lambda v:v.title())
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_22008\1730579423.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zomato5['name'] = zomato5['name'].apply(lambda v:v.title())

# %%
zomato5['online_order'].replace(('Yes','No'),(True,False),inplace = True)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_22008\3640234011.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zomato5['online_order'].replace(('Yes','No'),(True,False),inplace = True)

# %%
zomato5
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51709  136, SAP Labs India, KIADB Export Promotion In...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name  online_order  \
# 0                                                  Jalsa          True
# 1                                         Spice Elephant          True
# ...

# %%
zomato5['book_table'].replace(('Yes','No'),(True,False),inplace = True)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_22008\3794386327.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zomato5['book_table'].replace(('Yes','No'),(True,False),inplace = True)

# %%
zomato5.head()
# Out:
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#    online_order  book_table  rate  votes      location            rest_type  \
# 0          True        True   4.1    775  Banashankari        Casual Dining
# 1          True       False   4.1    787  Banashankari        Casual Dining
# 2          True       False   3.8    918  Banashankari  Cafe, Casual Dining
# 3         False       False   3.7     88  Banashankari          Quick Bites
# 4         False       False   3.8    166  Basavanagudi        Casual Dining
#
#                          cuisines   cost  \
# ...

# %%
zomato5['address'].factorize()
# Out:
# (array([   0,    1,    2, ..., 8725, 8786, 3444], dtype=int64),
#  Index(['942, 21st Main Road, 2nd Stage, Banashankari, Bangalore',
#         '2nd Floor, 80 Feet Road, Near Big Bazaar, 6th Block, Kathriguppe, 3rd Stage, Banashankari, Bangalore',
#         '1112, Next to KIMS Medical College, 17th Cross, 2nd Stage, Banashankari, Bangalore',
#         '1st Floor, Annakuteera, 3rd Stage, Banashankari, Bangalore',
#         '10, 3rd Floor, Lakshmi Associates, Gandhi Bazaar Main Road, Above Reliance Trends, Basavanagudi, Bangalore',
#         '37, 5-1, 4th Floor, Bosco Court, Gandhi Bazaar Main Road, Basavanagudi, Bangalore',
#         '19/1, New Timberyard Layout, Beside Satellite Bus Stop, Mysore Road, Bangalore',
#         '2469, 3rd Floor, 24th Cross, Opposite BDA Complex, 2nd Stage, Banashankari, Bangalore',
#         '1, 30th Main Road, 3rd Stage, Banashankari, Bangalore',
#         '2470, 21 Main Road, 25th Cross, Banashankari, Bangalore',
#         ...
# ...

# %%
zomato5['address'].factorize()[0]
# Out:
# array([   0,    1,    2, ..., 8725, 8786, 3444], dtype=int64)

# %%
def encode(zomato):
    for column in zomato5.columns[~zomato5.columns.isin(['rate','cost','votes'])]:
        zomato5[column] = zomato5[column].factorize()[0]
    return zomato5

# %%
zomato5_copy = zomato5.copy()

# %%
zomato5_encoded = encode(zomato5_copy)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_22008\1983312635.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zomato5[column] = zomato5[column].factorize()[0]

# %%
zomato5_encoded
# Out:
#        address  name  online_order  book_table  rate  votes  location  \
# 0            0     0             0           0   4.1    775         0
# 1            1     1             0           1   4.1    787         0
# 2            2     2             0           1   3.8    918         0
# 3            3     3             1           1   3.7     88         0
# 4            4     4             1           1   3.8    166         1
# ...        ...   ...           ...         ...   ...    ...       ...
# 51709     3137  2699             1           1   3.7     34        25
# 51711     8791  1716             1           1   2.5     81        25
# 51712     8725  6532             1           1   3.6     27        25
# 51715     8786  6568             1           0   4.3    236        56
# 51716     3444  6569             1           1   3.4     13        56
#
#        rest_type  cuisines   cost  reviews_list  menu_item  type  city
# ...

# %%
zomato5_encoded.corr()
# Out:
#                address      name  online_order  book_table      rate  \
# address       1.000000  0.682346      0.165707    0.021447 -0.036195
# name          0.682346  1.000000      0.231616   -0.033718 -0.046936
# online_order  0.165707  0.231616      1.000000   -0.054894 -0.069042
# book_table    0.021447 -0.033718     -0.054894    1.000000 -0.426027
# rate         -0.036195 -0.046936     -0.069042   -0.426027  1.000000
# votes        -0.010738 -0.043871      0.013278   -0.393270  0.435237
# location      0.614626  0.448705      0.048645   -0.032781  0.030363
# rest_type     0.030634  0.036212      0.136741   -0.226763  0.196933
# cuisines      0.238421  0.301793      0.049921   -0.225396  0.189624
# cost          0.003227 -0.084328     -0.180782    0.266651 -0.115346
# reviews_list  0.512074  0.339130      0.051440   -0.132809  0.159661
# menu_item     0.058929 -0.031798     -0.362114    0.040496  0.054942
# type          0.094137  0.116000      0.239236   -0.114302  0.034038
# ...

# %%
sns.heatmap(zomato5_encoded.corr())
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,10))
sns.heatmap(zomato5_encoded.corr())
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,10))
sns.heatmap(zomato5_encoded.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## data visualization EDA - Exploratary data analysis

# %%
zomato5
# Out:
#        address  name  online_order  book_table  rate  votes  location  \
# 0            0     0             0           0   4.1    775         0
# 1            1     1             0           1   4.1    787         0
# 2            2     2             0           1   3.8    918         0
# 3            3     3             1           1   3.7     88         0
# 4            4     4             1           1   3.8    166         1
# ...        ...   ...           ...         ...   ...    ...       ...
# 51709     3137  2699             1           1   3.7     34        25
# 51711     8791  1716             1           1   2.5     81        25
# 51712     8725  6532             1           1   3.6     27        25
# 51715     8786  6568             1           0   4.3    236        56
# 51716     3444  6569             1           1   3.4     13        56
#
#        rest_type  cuisines   cost  reviews_list  menu_item  type  city
# ...

# %%
zomato4.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'location', 'rest_type', 'cuisines', 'cost', 'reviews_list',
#        'menu_item', 'type', 'city'],
#       dtype='object')

# %%
sns.countplot(x='online_order',data=zomato4)
# Out:
# <AxesSubplot:xlabel='online_order', ylabel='count'>

# %%
sns.countplot(x='online_order',data=zomato4)
fig = plt.gcf()
fig.set_size_inches(5,5)
plt.title('Restaurants Delivering Online Order or Not')
# Out:
# Text(0.5, 1.0, 'Restaurants Delivering Online Order or Not')

# %%
sns.countplot(x='book_table',data=zomato4)
fig = plt.gcf()
fig.set_size_inches(5,5)
plt.title('Restaurants Allowing Online Table Booking')
# Out:
# Text(0.5, 1.0, 'Restaurants Allowing Online Table Booking')

# %%
pd.crosstab(zomato5['rate'],zomato5['book_table'])
# Out:
# book_table    0     1
# rate
# 1.8           0     5
# 2.0           0    11
# 2.1           0    24
# 2.2          13    13
# 2.3           0    51
# 2.4           0    66
# 2.5           2    98
# 2.6           4   245
# 2.7           4   299
# 2.8           6   574
# 2.9           9   792
# 3.0           9   981
# 3.1          10  1540
# 3.2          23  1821
# 3.3           5  2267
# 3.4          16  2428
# 3.5          86  2677
# 3.6          72  3214
# 3.7         218  3589
# 3.8         351  3465
# 3.9         556  3398
# 4.0         685  2459
# 4.1         988  1937
# 4.2         950  1204
# 4.3         759   923
# 4.4         777   369
# 4.5         423   233
# 4.6         133   167
# 4.7         117    50
# 4.8          43    23
# 4.9          40    15

# %%
Y = pd.crosstab(zomato5['rate'],zomato5['book_table'])

# %%
Y.div
# Out:
# <bound method flex_arith_method_FRAME.<locals>.f of book_table    0     1
# rate
# 1.8           0     5
# 2.0           0    11
# 2.1           0    24
# 2.2          13    13
# 2.3           0    51
# 2.4           0    66
# 2.5           2    98
# 2.6           4   245
# 2.7           4   299
# 2.8           6   574
# 2.9           9   792
# 3.0           9   981
# 3.1          10  1540
# 3.2          23  1821
# 3.3           5  2267
# 3.4          16  2428
# 3.5          86  2677
# 3.6          72  3214
# 3.7         218  3589
# 3.8         351  3465
# 3.9         556  3398
# 4.0         685  2459
# 4.1         988  1937
# 4.2         950  1204
# 4.3         759   923
# 4.4         777   369
# 4.5         423   233
# 4.6         133   167
# 4.7         117    50
# 4.8          43    23
# 4.9          40    15>

# %%
Y.sum(1).astype(float)
# Out:
# rate
# 1.8       5.0
# 2.0      11.0
# 2.1      24.0
# 2.2      26.0
# 2.3      51.0
# 2.4      66.0
# 2.5     100.0
# 2.6     249.0
# 2.7     303.0
# 2.8     580.0
# 2.9     801.0
# 3.0     990.0
# 3.1    1550.0
# 3.2    1844.0
# 3.3    2272.0
# 3.4    2444.0
# 3.5    2763.0
# 3.6    3286.0
# 3.7    3807.0
# 3.8    3816.0
# 3.9    3954.0
# 4.0    3144.0
# 4.1    2925.0
# 4.2    2154.0
# 4.3    1682.0
# 4.4    1146.0
# 4.5     656.0
# 4.6     300.0
# 4.7     167.0
# 4.8      66.0
# 4.9      55.0
# dtype: float64

# %%
Y.div(Y.sum(1).astype(float),axis=0) #booktable facility, 0 = Yes, 1 = No
# Out:
# book_table         0         1
# rate
# 1.8         0.000000  1.000000
# 2.0         0.000000  1.000000
# 2.1         0.000000  1.000000
# 2.2         0.500000  0.500000
# 2.3         0.000000  1.000000
# 2.4         0.000000  1.000000
# 2.5         0.020000  0.980000
# 2.6         0.016064  0.983936
# 2.7         0.013201  0.986799
# 2.8         0.010345  0.989655
# 2.9         0.011236  0.988764
# 3.0         0.009091  0.990909
# 3.1         0.006452  0.993548
# 3.2         0.012473  0.987527
# 3.3         0.002201  0.997799
# 3.4         0.006547  0.993453
# 3.5         0.031126  0.968874
# 3.6         0.021911  0.978089
# 3.7         0.057263  0.942737
# 3.8         0.091981  0.908019
# 3.9         0.140617  0.859383
# 4.0         0.217875  0.782125
# 4.1         0.337778  0.662222
# 4.2         0.441040  0.558960
# 4.3         0.451249  0.548751
# 4.4         0.678010  0.321990
# 4.5         0.644817  0.355183
# 4.6         0.443333  0.556667
# 4.7         0.700599  0.299401
# ...

# %%
Y.div(Y.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True) #booktable facility, 0 = Yes, 1 = No
# Out:
# <AxesSubplot:xlabel='rate'>

# %%
plt.rcParams['figure.figsize']=[10,10]
Y.div(Y.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True) #booktable facility, 0 = Yes, 1 = No
# Out:
# <AxesSubplot:xlabel='rate'>

# %%
plt.rcParams['figure.figsize']=[10,10]
Y.div(Y.sum(1).astype(float),axis=0).plot(kind='bar',stacked=True,color=['red','black']) #booktable facility, 0 = Yes, 1 = No
# Out:
# <AxesSubplot:xlabel='rate'>

# %%
zomato4['city']
# Out:
# 0        Banashankari
# 1        Banashankari
# 2        Banashankari
# 3        Banashankari
# 4        Banashankari
#              ...
# 51709      Whitefield
# 51711      Whitefield
# 51712      Whitefield
# 51715      Whitefield
# 51716      Whitefield
# Name: city, Length: 41302, dtype: object

# %%
sns.countplot(x='city',data=zomato4)
# Out:
# <AxesSubplot:xlabel='city', ylabel='count'>

# %%
sns.countplot(x='city',data=zomato4)
sns.countplot(x='city',data=zomato4).set_xticklabels(sns.countplot(x='city',data=zomato4).get_xticklabels(),rotation=90,ha='right')
# Out:
# [Text(0, 0, 'Banashankari'),
#  Text(1, 0, 'Bannerghatta Road'),
#  Text(2, 0, 'Basavanagudi'),
#  Text(3, 0, 'Bellandur'),
#  Text(4, 0, 'Brigade Road'),
#  Text(5, 0, 'Brookefield'),
#  Text(6, 0, 'BTM'),
#  Text(7, 0, 'Church Street'),
#  Text(8, 0, 'Electronic City'),
#  Text(9, 0, 'Frazer Town'),
#  Text(10, 0, 'HSR'),
#  Text(11, 0, 'Indiranagar'),
#  Text(12, 0, 'Jayanagar'),
#  Text(13, 0, 'JP Nagar'),
#  Text(14, 0, 'Kalyan Nagar'),
#  Text(15, 0, 'Kammanahalli'),
#  Text(16, 0, 'Koramangala 4th Block'),
#  Text(17, 0, 'Koramangala 5th Block'),
#  Text(18, 0, 'Koramangala 6th Block'),
#  Text(19, 0, 'Koramangala 7th Block'),
#  Text(20, 0, 'Lavelle Road'),
#  Text(21, 0, 'Malleshwaram'),
#  Text(22, 0, 'Marathahalli'),
#  Text(23, 0, 'MG Road'),
#  Text(24, 0, 'New BEL Road'),
#  Text(25, 0, 'Old Airport Road'),
#  Text(26, 0, 'Rajajinagar'),
#  Text(27, 0, 'Residency Road'),
#  Text(28, 0, 'Sarjapur Road'),
#  Text(29, 0, 'Whitefield')]

# %%
sns.countplot(x='city',data=zomato4)
sns.countplot(x='city',data=zomato4).set_xticklabels(sns.countplot(x='city',data=zomato4).get_xticklabels(),rotation=90,ha='right')
plt.show()

# %%
sns.countplot(x='rest_type',data=zomato4)
sns.countplot(x='rest_type',data=zomato4).set_xticklabels(sns.countplot(x='rest_type',data=zomato4).get_xticklabels(),rotation=90,ha='right')
plt.show()

# %%
sns.countplot(x='rest_type',data=zomato4)
sns.countplot(x='rest_type',data=zomato4).set_xticklabels(sns.countplot(x='rest_type',data=zomato4).get_xticklabels(),rotation=90,ha='right')
fig=plt.gcf()
fig.set_size_inches(14,14)
plt.show()

# %%
sns.countplot(x='type',data=zomato4)
sns.countplot(x='type',data=zomato4).set_xticklabels(sns.countplot(x='type',data=zomato4).get_xticklabels(),rotation=90,ha='right')
plt.show()

# %%
zomato4['name']
# Out:
# 0                                                    Jalsa
# 1                                           Spice Elephant
# 2                                          San Churro Cafe
# 3                                    Addhuri Udupi Bhojana
# 4                                            Grand Village
#                                ...
# 51709                           The Farm House Bar n Grill
# 51711                                              Bhagini
# 51712    Best Brews - Four Points by Sheraton Bengaluru...
# 51715    Chime - Sheraton Grand Bengaluru Whitefield Ho...
# 51716                         The Nest - The Den Bengaluru
# Name: name, Length: 41302, dtype: object

# %%
zomato4['name'].value_counts()
# Out:
# Cafe Coffee Day          86
# Onesta                   85
# Empire Restaurant        69
# Kanti Sweets             68
# Five Star Chicken        68
#                          ..
# Food Court                1
# Silver Spoon              1
# Shivaji Maratha Hotel     1
# SLV Delite                1
# SeeYa Restaurant          1
# Name: name, Length: 6657, dtype: int64

# %%
zomato4['name'].value_counts()[:15]
# Out:
# Cafe Coffee Day      86
# Onesta               85
# Empire Restaurant    69
# Kanti Sweets         68
# Five Star Chicken    68
# Just Bake            67
# Baskin Robbins       62
# Petoo                60
# Pizza Hut            60
# KFC                  60
# Smoor                59
# McDonald's           59
# Domino's Pizza       59
# Subway               59
# Sweet Truth          58
# Name: name, dtype: int64

# %%
chains = zomato4['name'].value_counts()[:15]

# %%
type(chains)
# Out:
# pandas.core.series.Series

# %%
sns.barplot(x=chains,y=chains.index)
# Out:
# <AxesSubplot:xlabel='name'>
